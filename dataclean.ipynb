# %%
import pandas as pd

# %%
data20 = pd.concat(map(pd.read_csv, ['202006-citibike-tripdata.csv', '202007-citibike-tripdata.csv', '202008-citibike-tripdata.csv']), ignore_index=True)
data20
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                1062  2020-06-01 00:00:03.3720  2020-06-01 00:17:46.2080
# 1                3810  2020-06-01 00:00:03.5530  2020-06-01 01:03:33.9360
# 2                1017  2020-06-01 00:00:09.6140  2020-06-01 00:17:06.8330
# 3                 226  2020-06-01 00:00:12.1780  2020-06-01 00:03:58.8640
# 4                1437  2020-06-01 00:00:21.2550  2020-06-01 00:24:18.9650
# ...               ...                       ...                       ...
# 6317590          1562  2020-08-31 23:59:29.7690  2020-09-01 00:25:31.9660
# 6317591          1023  2020-08-31 23:59:32.1320  2020-09-01 00:16:35.3710
# 6317592           600  2020-08-31 23:59:33.0920  2020-09-01 00:09:33.4670
# 6317593           737  2020-08-31 23:59:35.7900  2020-09-01 00:11:53.2310
# 6317594           373  2020-08-31 23:59:45.3470  2020-09-01 00:05:59.1630
#
#          start station id               start station name  \
# ...

# %%
new = data20["starttime"].str.split(" ", n=1, expand = True)
data20["start date"]= new[0]
data20["start time"]= new[1]
data20.drop(columns =["starttime"], inplace = True)
data20
# Out:
#          tripduration                  stoptime  start station id  \
# 0                1062  2020-06-01 00:17:46.2080              3419
# 1                3810  2020-06-01 01:03:33.9360               366
# 2                1017  2020-06-01 00:17:06.8330               389
# 3                 226  2020-06-01 00:03:58.8640              3255
# 4                1437  2020-06-01 00:24:18.9650               367
# ...               ...                       ...               ...
# 6317590          1562  2020-09-01 00:25:31.9660               298
# 6317591          1023  2020-09-01 00:16:35.3710              3508
# 6317592           600  2020-09-01 00:09:33.4670               320
# 6317593           737  2020-09-01 00:11:53.2310              3318
# 6317594           373  2020-09-01 00:05:59.1630              3423
#
#                       start station name  start station latitude  \
# 0                    Douglass St & 4 Ave               40.679279
# ...

# %%
new = data20["stoptime"].str.split(" ", n=1, expand = True)
data20["stop date"]= new[0]
data20["stop time"]= new[1]
data20.drop(columns =["stoptime"], inplace = True)
data20
# Out:
#          tripduration  start station id               start station name  \
# 0                1062              3419              Douglass St & 4 Ave
# 1                3810               366         Clinton Ave & Myrtle Ave
# 2                1017               389              Broadway & Berry St
# 3                 226              3255                  8 Ave & W 31 St
# 4                1437               367          E 53 St & Lexington Ave
# ...               ...               ...                              ...
# 6317590          1562               298          3 Ave & Schermerhorn St
# 6317591          1023              3508  St Nicholas Ave & Manhattan Ave
# 6317592           600               320           Leonard St & Church St
# 6317593           737              3318                  2 Ave & E 96 St
# 6317594           373              3423  West Drive & Prospect Park West
#
#          start station latitude  start station longitude  end station id  \
# ...

# %%
data20= data20[data20.gender !=0]
data20
# Out:
#          tripduration  start station id               start station name  \
# 0                1062              3419              Douglass St & 4 Ave
# 2                1017               389              Broadway & Berry St
# 4                1437               367          E 53 St & Lexington Ave
# 5                 355               248            Laight St & Hudson St
# 6                  99              3232              Bond St & Fulton St
# ...               ...               ...                              ...
# 6317589          1111               439                   E 4 St & 2 Ave
# 6317590          1562               298          3 Ave & Schermerhorn St
# 6317591          1023              3508  St Nicholas Ave & Manhattan Ave
# 6317592           600               320           Leonard St & Church St
# 6317593           737              3318                  2 Ave & E 96 St
#
#          start station latitude  start station longitude  end station id  \
# ...

# %%
data20.to_csv("June-Aug 2020 data.csv", index=False, header=True)
